# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2
import numpy as np

import eyetrack

# %%
im = cv2.imread('../images/face.jpg')

im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

# plt.axis("off")
plt.imshow(im_gray, cmap='gray')
plt.show()

# %%
coords = eyetrack.detect_pupils(im_gray)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-ad11c98a32fc> in <module>()
# ----> 1 coords = eyetrack.detect_pupils(im_gray)
#
# AttributeError: 'module' object has no attribute 'detect_pupils'
